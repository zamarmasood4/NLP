# %%
import os
import spacy
nlp=spacy.load("en_core_web_sm")
from autocorrect import Speller
spell = Speller()
import nltk
from nltk import sent_tokenize
path='D:\\University Data\\NLP\\Deep Learning\\Text_Files' 
filepath=os.listdir(path)

D_F=[]
def filetext (filename):
    for file in filename:
        text=open(path+"\\"+file,"r").read() 
        to_store_sentences=[]
        sent_=sent_tokenize(text)
        for sentence in sent_:
            to_store_sentences.append(sentence)
        index=[text,type(text),to_store_sentences] 
        D_F.append(index)

filetext(filepath)




D_S_P=[]
for sentence in D_F:
    D_S_P.append(sentence[2])

def PreProcessingspacy(text):
    text=spell(text)
    token=[]
    tokens=nlp(text)
    token=[tokens]
    pos=[]
    for w in tokens:
        pos.append(w.text)
        pos.append(w.pos_)
    token_without_stopwords = [w.text for w in tokens if not  w.is_stop]    
    token_in_lowercase = [w.lower() for w in token_without_stopwords]
    lemmas = [w.lemma_ for w in tokens if not (w.is_stop or not w.is_alpha)]
    lemmas=[w.lower() for w in lemmas]
    
    return [token,pos,token_without_stopwords,token_in_lowercase,lemmas]

i=0
j=0
for file in D_S_P:
    for sentence in file:
        data=PreProcessingspacy(sentence)
        sentence=[sentence,data]   
        D_S_P[i][j]=sentence
        j=j+1
    j=0
    i=i+1


import pickle
save1=open("PreProcessed_Data.pickle","wb")
pickle.dump(D_S_P,save1)
save1.close()


import pickle
file3=open("PreProcessed_Data.pickle","rb")
D_S_P=pickle.load(file3)

BOW=[]
for index in range(0,len(D_S_P)):
    for index1 in range(0,len(D_S_P[index])):
        lemmas=D_S_P[index][index1][-1][-1]
        for l in lemmas:
            BOW.append(l)

print(BOW)
print(len(BOW))

Freuency={}
for word in BOW:
    if word in Freuency:
        Freuency[word]=Freuency[word]+1
    else:
        Freuency[word]=1


listed=list(Freuency.items())

def insertionsort(Freuency):
    for i in range(1, len(Freuency)):
        valuetochange=Freuency[i]
        print(valuetochange,end="|")
        a=i-1
        while a >= 0 and Freuency[a][1] < valuetochange[1]:
            Freuency[a+1]=Freuency[a]
            a=a-1
        Freuency[a+1]=valuetochange

insertionsort(listed)
sortedd = dict(listed)

print(sortedd)
top50=[listed[i] for i in range(0,50)]
top50sortedd=dict(top50)
print(len(top50sortedd))
print(top50sortedd)
# Out:
# ['enigmatic', 'world', 'quantum', 'mechanics', 'introduction', 'realm', 'quantum', 'mechanic', 'stand', 'intriguing', 'enigmatic', 'domain', 'modern', 'science', 'principle', 'defy', 'common', 'sense', 'govern', 'behavior', 'particle', 'small', 'scale', 'shape', 'fabric', 'universe', 'comprehensive', 'exploration', 'delve', 'intricacy', 'quantum', 'mechanic', 'travel', 'mystery', 'layer', 'layer', 'chapter', 'birth', 'quantum', 'mechanics', 'journey', 'quantum', 'mechanic', 'begin', 'early', 'century', 'time', 'great', 'upheaval', 'scientific', 'community', 'classical', 'physic', 'long', 'reign', 'supreme', 'encounter', 'profound', 'challenge', 'confront', 'behavior', 'subtopic', 'particle', 'groundbreaking', 'work', 'pioneer', 'max', 'planck', 'albert', 'einstein', 'niels', 'bor', 'lay', 'foundation', 'new', 'era', 'understanding', 'chapter', 'wave', 'particle', 'quality', 'battling', 'concept', 'quantum', 'mechanic', 'wave', 'particle', 'duality', 'unlike', 'classical', 'particle', 'exhibit', 'strictly', 'particle', 'like', 'behavior', 'particle', 'quantum', 'level', 'display', 'wave', 'like', 'property', 'dual', 'nature', 'famously', 'illustrate', 'double', 'slit', 'experiment', 'reveal', 'wave', 'like', 'interference', 'pattern', 'produce', 'particle', 'electron', 'chapter', 'uncertainty', 'principle', 'werner', 'heidelberg', 'uncertainty', 'principle', 'introduce', 'fundamental', 'limit', 'ability', 'measure', 'certain', 'pair', 'property', 'particle', 'simultaneously', 'principle', 'shatter', 'deterministic', 'worldview', 'classical', 'physic', 'assert', 'quantum', 'level', 'act', 'measurement', 'disturb', 'system', 'observe', 'implication', 'principle', 'reverberate', 'quantum', 'mechanic', 'shape', 'understanding', 'probability', 'randomness', 'chapter', 'quantum', 'entanglement', 'perplexing', 'phenomenon', 'quantum', 'mechanic', 'entanglement', 'particle', 'entangled', 'property', 'intertwine', 'way', 'state', 'particle', 'instantaneous', 'influence', 'state', 'regardless', 'distance', 'phenomenon', 'famously', 'characterize', 'einstein', 'spooky', 'action', 'distance', 'challenge', 'intuitive', 'notion', 'space', 'time', 'causality', 'chapter', 'cat', 'quantum', 'superposition', 'cat', 'thought', 'experiment', 'encapsulate', 'concept', 'quantum', 'superposition', 'vivid', 'paradoxical', 'scenario', 'accord', 'quantum', 'mechanic', 'particle', 'exist', 'multiple', 'state', 'simultaneously', 'observe', 'point', 'collapse', 'single', 'state', 'principle', 'give', 'rise', 'concept', 'superposition', 'particle', 'combination', 'state', 'measure', 'lead', 'bizarre', 'counterintuitive', 'outcome', 'chapter', 'quantum', 'computing', 'advent', 'quantum', 'compute', 'promise', 'revolutionize', 'field', 'information', 'technology', 'harvest', 'principle', 'quantum', 'mechanic', 'perform', 'computation', 'speed', 'far', 'capability', 'classical', 'computer', 'quantum', 'bit', 'quit', 'exist', 'superposition', 'entanglement', 'enable', 'quantum', 'computer', 'solve', 'certain', 'problem', 'exponentially', 'fast', 'classical', 'counterpart', 'despite', 'immense', 'promise', 'quantum', 'computing', 'significant', 'challenge', 'remain', 'realize', 'practical', 'scalable', 'quantum', 'processor', 'chapter', 'quantum', 'teleportation', 'cryptography', 'quantum', 'teleportation', 'process', 'quantum', 'state', 'particle', 'transfer', 'distant', 'particle', 'hold', 'profound', 'implication', 'communication', 'cryptography', 'unlike', 'classical', 'information', 'transfer', 'rely', 'transmission', 'physical', 'particle', 'electromagnetic', 'signal', 'quantum', 'teleportation', 'allow', 'instantaneous', 'transfer', 'quantum', 'information', 'distant', 'location', 'capability', 'revolutionize', 'secure', 'communication', 'cryptography', 'offer', 'unparalleled', 'level', 'privacy', 'encryption', 'chapter', 'future', 'quantum', 'mechanics', 'peer', 'future', 'quantum', 'mechanic', 'encounter', 'landscape', 'countless', 'potential', 'untold' ...
# 394
# ('world', 1)|('quantum', 33)|('mechanics', 3)|('introduction', 1)|('realm', 2)|('mechanic', 11)|('stand', 1)|('intriguing', 1)|('domain', 1)|('modern', 1)|('science', 1)|('principle', 7)|('defy', 1)|('common', 1)|('sense', 1)|('govern', 1)|('behavior', 3)|('particle', 17)|('small', 1)|('scale', 1)|('shape', 2)|('fabric', 1)|('universe', 3)|('comprehensive', 1)|('exploration', 1)|('delve', 1)|('intricacy', 1)|('travel', 1)|('mystery', 2)|('layer', 2)|('chapter', 8)|('birth', 1)|('journey', 2)|('begin', 1)|('early', 1)|('century', 1)|('time', 2)|('great', 1)|('upheaval', 1)|('scientific', 1)|('community', 1)|('classical', 6)|('physic', 2)|('long', 1)|('reign', 1)|('supreme', 1)|('encounter', 2)|('profound', 2)|('challenge', 3)|('confront', 1)|('subtopic', 1)|('groundbreaking', 1)|('work', 1)|('pioneer', 1)|('max', 1)|('planck', 1)|('albert', 1)|('einstein', 2)|('niels', 1)|('bor', 1)|('lay', 1)|('foundation', 1)|('new', 1)|('era', 1)|('understanding', 3)|('wave', 4)|('quality', 1)|('battling', 1)|('concept', 3)|('duality', 1)|('unlike', 2)|('exhibit', 1)|('strictly', 1)|('like', 3)|('level', 3)|('display', 1)|('property', 3)|('dual', 1)|('nature', 1)|('famously', 2)|('illustrate', 1)|('double', 1)|('slit', 1)|('experiment', 2)|('reveal', 1)|('interference', 1)|('pattern', 1)|('produce', 1)|('electron', 1)|('uncertainty', 3)|('werner', 1)|('heidelberg', 1)|('introduce', 1)|('fundamental', 1)|('limit', 1)|('ability', 1)|('measure', 2)|('certain', 2)|('pair', 1)|('simultaneously', 2)|('shatter', 1)|('deterministic', 1)|('worldview', 1)|('assert', 1)|('act', 1)|('measurement', 1)|('disturb', 1)|('system', 1)|('observe', 2)|('implication', 3)|('reverberate', 1)|('probability', 2)|('randomness', 1)|('entanglement', 3)|('perplexing', 1)|('phenomenon', 2)|('entangled', 1)|('intertwine', 1)|('way', 1)|('state', 6)|('instantaneous', 2)|('influence', 1)|('regardless', 1)|('distance', 2)|('characterize', 1)|('spooky', 1)|('action', 1)|('intuitive', 1)|('notion', 1)|('space', 1)|('causality', 1)|('cat', 2)|('superposition', 4)|('thought', 1)|('encapsulate', 1)|('vivid', 1)|('paradoxical', 1)|('scenario', 1)|('accord', 1)|('exist', 2)|('multiple', 1)|('point', 1)|('collapse', 1)|('single', 1)|('give', 1)|('rise', 1)|('combination', 1)|('lead', 1)|('bizarre', 1)|('counterintuitive', 1)|('outcome', 1)|('computing', 3)|('advent', 1)|('compute', 1)|('promise', 2)|('revolutionize', 2)|('field', 1)|('information', 3)|('technology', 1)|('harvest', 1)|('perform', 1)|('computation', 1)|('speed', 1)|('far', 2)|('capability', 2)|('computer', 2)|('bit', 1)|('quit', 1)|('enable', 1)|('solve', 1)|('problem', 1)|('exponentially', 1)|('fast', 1)|('counterpart', 1)|('despite', 1)|('immense', 1)|('significant', 1)|('remain', 2)|('realize', 1)|('practical', 1)|('scalable', 1)|('processor', 1)|('teleportation', 4)|('cryptography', 3)|('process', 1)|('transfer', 3)|('distant', 2)|('hold', 1)|('communication', 2)|('rely', 1)|('transmission', 1)|('physical', 1)|('electromagnetic', 1)|('signal', 1)|('allow', 1)|('location', 1)|('secure', 1)|('offer', 1)|('unparalleled', 1)|('privacy', 1)|('encryption', 1)|('future', 2)|('peer', 1)|('landscape', 1)|('countless', 1)|('potential', 1)|('untold', 1)|('discovery', 1)|('biology', 1)|('extend', 1)|('confine', 1)|('laboratory', 1)|('permit', 1)|('aspect', 1)|('life', 1)|('escape', 1)|('conclusion', 1)|('vast', 1)|('expanse', 1)|('find', 1)|('tapestry', 1)|('complexity', 1)|('wonder', 1)|('dance', 1)|('rhythm', 1)|('unsolved', 1)|('question', 1)|('unanswered', 1)|('heart', 1)|('continue', 1)|('inspire', 1)|('awe', 1)|('fascination', 1)|('reckon', 1)|('explore', 1)|('depth', 1)|('unlock', 1)|('secret', 1)|{'quantum': 33, 'particle': 17, 'mechanic': 11, 'chapter': 8, 'principle': 7, 'classical': 6, 'state': 6, 'wave': 4, 'superposition': 4, 'teleportation': 4, 'mechanics': 3, 'behavior': 3, 'universe': 3, 'challenge': 3, 'understanding': 3, 'concept': 3, 'like': 3, 'level': 3, 'property': 3, 'uncertainty': 3, 'implication': 3,  ...
# 50
# {'quantum': 33, 'particle': 17, 'mechanic': 11, 'chapter': 8, 'principle': 7, 'classical': 6, 'state': 6, 'wave': 4, 'superposition': 4, 'teleportation': 4, 'mechanics': 3, 'behavior': 3, 'universe': 3, 'challenge': 3, 'understanding': 3, 'concept': 3, 'like': 3, 'level': 3, 'property': 3, 'uncertainty': 3, 'implication': 3, 'entanglement': 3, 'computing': 3, 'information': 3, 'cryptography': 3, 'transfer': 3, 'enigmatic': 2, 'realm': 2, 'shape': 2, 'mystery': 2, 'layer': 2, 'journey': 2, 'time': 2, 'physic': 2, 'encounter': 2, 'profound': 2, 'einstein': 2, 'unlike': 2, 'famously': 2, 'experiment': 2, 'measure': 2, 'certain': 2, 'simultaneously': 2, 'observe': 2, 'probability': 2, 'phenomenon': 2, 'instantaneous': 2, 'distance': 2, 'cat': 2, 'exist': 2}
